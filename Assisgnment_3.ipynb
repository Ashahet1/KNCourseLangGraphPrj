# %% [markdown]
# # Problem Statement:
#
# Designing an end-to-end application that orchestrates the workflow between:
#
# An orchestrator component that manages the overall process
# A synthesizer component that generates specific outputs based on instructions
#
# For our use case, let's create a Technical Documentation Generator that:
#
# Takes high-level requirements as input
# Breaks them down into specific documentation sections
# Generates comprehensive technical documentation with code examples
# Iteratively refines the documentation based on feedback
#
# **Explanation of Approach**
# My approach to this Langgraph application focuses on several key aspects:
#
# **Orchestrator-Synthesizer Architecture**:
#
# The orchestrator manages the workflow and delegates tasks
# The synthesizer generates content based on specific instructions
# I've added a reviewer component to provide feedback and ensure quality
#
#
# **State Management:**
#
# Using Langgraph's StateGraph to maintain document state throughout generation
# Clear state transitions between planning, generating, reviewing, and refining
#
#
# **Open Source Model Integration:**
#
# Primary implementation using Ollama with local open-source models (Llama and Mistral)
# Fallback to other models if local models aren't available
#
#
# **Debugging with Langsmith:**
#
# Comprehensive tracing of all operations
# Detailed metrics for performance analysis
# Tools for identifying bottlenecks and errors
#
#
# **Iterative Refinement:**
#
# The workflow includes feedback loops for content improvement
# Maximum of 2 refinement iterations to prevent infinite loops

# %% [markdown]
# ### **🚀 Steps for Implementing the Orchestrator and synthesizer**

# %% [markdown]
#  **Step 1: Set Up the Environment**
#    - Install required libraries: `langchain`, `langgraph`, `transformers`, `huggingface_hub`, `langsmith`.
#    - Configure LangSmith for debugging and monitoring.
#
#   **!pip install -r requirements.txt**

# %%
import os
from typing import Dict, List, Tuple, TypedDict, Annotated, Literal
import json
from langgraph.graph import StateGraph, END
from langgraph.prebuilt import ToolNode
from langchain_openai import ChatOpenAI
from langchain_community.llms import Ollama
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_core.tools import tool
from langchain.agents import AgentExecutor, create_openai_tools_agent
from langsmith import Client
from langchain_core.tracers import LangChainTracer
from langchain_core.callbacks.manager import CallbackManager
from langchain_core.tracers.langchain import wait_for_all_tracers
from langgraph.prebuilt import ToolNode
from IPython.display import Image, display

# Initialize tracer
tracer = LangChainTracer(project_name="technical-doc-project")
callback_manager = CallbackManager([tracer])


import os
from dotenv import load_dotenv
load_dotenv()

import os

os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_ENDPOINT"] = "https://api.smith.langchain.com"  # Ensure the correct endpoint
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")  # Ensure the API key is set

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
os.environ["LANGSMITH_API_KEY"] = os.getenv("LANGSMITH_API_KEY")

langsmith_client=Client()

# %% [markdown]
# **Step2: Integrate Open-Source LLM**
#    - Use **OLLAMA** (e.g., `llama3:8b`).

# %%
planner_model = ChatOpenAI(model="gpt-4o")
synthesizer_model = ChatOpenAI(model="gpt-4o")
reviewer_model = ChatOpenAI(model="gpt-4o")

# %%
# Define state schema
class DocumentState(TypedDict):
    # Input and requirements
    requirements: str
    # Planning
    sections: List[Dict[str, str]]
    section_index: int
    # Content generation
    current_section: Dict[str, str]
    section_content: Dict[str, str]
    # Feedback and iteration
    feedback: List[str]
    iteration_count: int
    # Final output
    complete_document: str
    # Flow control
    status: Literal["planning", "generating", "reviewing", "refining", "complete"]

# %%
# Define the nodes
# 1. Planner Node - Breaks down requirements into sections
from langsmith import trace

def plan_document(state: DocumentState) -> DocumentState:
    prompt = ChatPromptTemplate.from_messages([
        SystemMessage(content="""You are a technical documentation planner. 
        Your task is to break down high-level requirements into specific document sections.
        Each section should have a title, purpose, and brief description of what it should contain."""),
        HumanMessage(content=f"Please create a detailed outline for technical documentation based on these requirements: {state['requirements']}")
    ])

    response = planner_model.invoke(prompt.format_messages())

    # 🔍 Debugging: Print LLM response
    print("\n🔎 Planner LLM Response:\n", response.content)

    # If the response is empty, return an error message
    if not response.content.strip():
        return {**state, "sections": [{"title": "Error", "description": "No response from LLM", "status": "error"}]}

    try:
        raw_sections = response.content.split("## ")[1:]  # Split into sections
        sections = []

        for section in raw_sections:
            lines = section.strip().split("\n")
            title = lines[0].strip()
            description = "\n".join(lines[1:]).strip()

            sections.append({
                "title": title,
                "description": description,
                "status": "pending"
            })

    except Exception as e:
        sections = [{"title": "Error in section parsing", 
                     "description": f"Error: {str(e)}\nRaw response: {response.content}",
                     "status": "error"}]

    return {**state, "sections": sections, "section_index": 0, "status": "generating"}



# 2. Synthesizer Node - Generates content for each section
def generate_section_content(state: DocumentState) -> DocumentState:
    if state["section_index"] >= len(state["sections"]):
        return {**state, "status": "complete"}

    current_section = state["sections"][state["section_index"]]

    prompt = ChatPromptTemplate.from_messages([
        SystemMessage(content="""You are a technical documentation writer.
        Create comprehensive, clear content for the assigned section.
        Include code examples where appropriate.
        Format using markdown with proper headers, code blocks, and explanations."""),
        HumanMessage(content=f"""
        Project Requirements: {state['requirements']}
        
        Create content for the following section:
        
        ## {current_section['title']}
        
        Description: {current_section['description']}
        """)
    ])

    response = synthesizer_model.invoke(prompt.format_messages())

    # 🔍 Debugging: Print Synthesizer Response
    print(f"\n🔎 Synthesizer LLM Response for Section '{current_section['title']}':\n", response.content)

    if not response.content.strip():
        response.content = "⚠️ Error: No content generated."

    # Store the generated content
    section_content = state.get("section_content", {})
    section_content[current_section["title"]] = response.content

    return {
        **state,
        "current_section": current_section,
        "section_content": section_content,
        "status": "reviewing"
    }


# 3. Reviewer Node - Reviews the content and provides feedback
def review_section(state: DocumentState) -> DocumentState:
        current_section = state["current_section"]
        section_content = state["section_content"][current_section["title"]]
        
        prompt = ChatPromptTemplate.from_messages([
            SystemMessage(content="""You are a technical documentation reviewer.
            Evaluate the content provided for accuracy, clarity, and completeness.
            Provide specific, actionable feedback for improvements."""),
            HumanMessage(content=f"""
            Project Requirements: {state['requirements']}
            
            Section Purpose: {current_section['description']}
            
            Content to Review:
            
            {section_content}
            
            Provide feedback on this content:
            """)
        ])
        
        response = reviewer_model.invoke(prompt.format_messages())
        
        feedback = response.content
        current_feedback = state.get("feedback", [])
        current_feedback.append(feedback)
        
        # Check if feedback contains substantial change requests
        needs_refinement = "improve" in feedback.lower() or "revise" in feedback.lower() or "change" in feedback.lower()
        iteration_count = state.get("iteration_count", 0)
        
        if needs_refinement and iteration_count < 2:  # Limit to 2 refinement iterations
            return {
                **state,
                "feedback": current_feedback,
                "iteration_count": iteration_count + 1,
                "status": "refining"
            }
        else:
            # Move to the next section
            sections = state["sections"]
            sections[state["section_index"]]["status"] = "completed"
            
            return {
                **state,
                "feedback": current_feedback,
                "sections": sections,
                "section_index": state["section_index"] + 1,
                "iteration_count": 0,
                "status": "generating" if state["section_index"] + 1 < len(state["sections"]) else "complete"
            }

# 4. Refiner Node - Refines content based on feedback
def refine_section(state: DocumentState) -> DocumentState:
        current_section = state["current_section"]
        section_content = state["section_content"][current_section["title"]]
        latest_feedback = state["feedback"][-1]
        
        prompt = ChatPromptTemplate.from_messages([
            SystemMessage(content="""You are a technical documentation writer.
            Revise the content based on the feedback provided.
            Maintain markdown formatting with proper headers, code blocks, and explanations."""),
            HumanMessage(content=f"""
            Original Content:
            
            {section_content}
            
            Feedback Received:
            
            {latest_feedback}
            
            Please revise the content addressing this feedback:
            """)
        ])
        
        response = synthesizer_model.invoke(prompt.format_messages())
        
        # Update the refined content
        refined_content = response.content
        section_content = state.get("section_content", {})
        section_content[current_section["title"]] = refined_content
        
        return {
            **state,
            "section_content": section_content,
            "status": "reviewing"
    }

# 5. Finalizer Node - Compiles the final document
def compile_document(state: DocumentState) -> DocumentState:
    sections = state["sections"]
    section_content = state["section_content"]

    document = f"# {state['requirements']} Documentation\n\n"

    for section in sections:
        title = section["title"]
        content = section_content.get(title, "").strip()

        if content:
            document += f"\n## {title}\n\n{content}\n"
        else:
            document += f"\n## {title}\n\n⚠️ (No content generated)\n"

    return {**state, "complete_document": document, "status": "complete"}

# %%
# Create the graph
def create_workflow_graph():
    # Define the graph
    workflow = StateGraph(DocumentState)
    
    # Add nodes
    workflow.add_node("planner", plan_document)
    workflow.add_node("synthesizer", generate_section_content)
    workflow.add_node("reviewer", review_section)
    workflow.add_node("refiner", refine_section)
    workflow.add_node("finalizer", compile_document)
    
    # Add edges based on state transitions
    workflow.add_edge("planner", "synthesizer")
    workflow.add_conditional_edges(
        "synthesizer",
        lambda state: state["status"],
        {
            "reviewing": "reviewer",
            "complete": "finalizer"
        }
    )
    workflow.add_conditional_edges(
        "reviewer",
        lambda state: state["status"],
        {
            "refining": "refiner",
            "generating": "synthesizer",
            "complete": "finalizer"
        }
    )
    workflow.add_edge("refiner", "reviewer")
    workflow.add_edge("finalizer", END)
    
    # Set the entry point
    workflow.set_entry_point("planner")
    
    return workflow.compile()

# Main execution function
def generate_documentation(requirements: str) -> str:
    # Initialize state
    initial_state = {
        "requirements": requirements,
        "sections": [],
        "section_index": 0,
        "current_section": {},
        "section_content": {},
        "feedback": [],
        "iteration_count": 0,
        "complete_document": "",
        "status": "planning"
    }
    
    # Create and run the graph
    graph = create_workflow_graph()
    config = {"recursion_limit": 50}  # Adjust based on your process needs
    final_state = graph.invoke(initial_state, config=config)
    
    return final_state["complete_document"]

# %%
# Example usage
if __name__ == "__main__":
    requirements = """
    Create comprehensive documentation for a Python-based data processing API that handles CSV and JSON data.
    The API should support data validation, transformation, and export to multiple formats.
    Include installation instructions, API reference, and usage examples.
    """
    
    result = generate_documentation(requirements)
    
    # Save the result to a file
    with open("generated_documentation.md", "w") as f:
        f.write(result)
    
    print("Documentation generated successfully!")
# Out:
# 🔎 Planner LLM Response:
#  # Technical Documentation Outline for Python-Based Data Processing API
#
# ## 1. Introduction
# **Purpose:** Provide an overview of the API, including its main functionalities and use cases.
# - Brief description of the API, its capabilities, and the types of data it handles (CSV and JSON).
# - Overview of key features such as data validation, transformation, and export capabilities.
# - Use case examples where the API could be beneficial (e.g., data cleaning, data integration tasks).
#
# ## 2. Getting Started
# **Purpose:** Guide users on how to install and configure the API.
# - **System Requirements:**
#   - List of compatible operating systems and required software (e.g., Python version, dependencies).
# - **Installation Instructions:**
#   - Step-by-step procedure for installing the API using package managers (e.g., pip).
#   - Instructions for setting up the API in a development environment.
# - **Configuration:**
#   - Guide on configuring the API settings, if applicable.
#   - Details on necessary configurations for initial setup (e.g., environment variables).
#
# ## 3. API Architecture
# **Purpose:** Explain the design and structure of the API to help understand its components and workflow.
# - **Overview of API Components:**
#   - Description of key components and their roles (e.g., data validator, transformer).
# - **Workflow Diagram:**
#   - Visual representation of data flow from input to output through the API.
# - **Modular Description:**
#   - Explanation of how different modules interact within the API.
#
# ## 4. Data Validation
# **Purpose:** Explain the data validation capabilities and how to configure and use them.
# - **Validation Features:**
#   - Supported validation types (e.g., schema validation, data type checks).
# - **Configuration and Customization:**
#   - Instructions on setting up validation rules.
#   - Examples of predefined rules and how to create custom ones.
# - **Error Handling:**
#   - Procedures for handling validation errors and logs.
#
# ## 5. Data Transformation
# **Purpose:** Describe the transformation features of the API and how to implement them.
# - **Transformation Capabilities:**
#   - Supported transformation functions (e.g., data normalization, filtering).
# - **Applying Transformations:**
#   - Instructions on applying transformations to data sets.
#   - Examples of common transformations and sample code snippets.
#
# ## 6. Data Export
# **Purpose:** Detail the export options supported by the API and how to utilize them.
# - **Supported Formats:**
#   - List of export formats (e.g., CSV, JSON, XML).
# - **Export Instructions:**
#   - Guide on exporting processed data to various formats.
#   - Example use cases for different export options.
#
# ## 7. API Reference
# **Purpose:** Provide a comprehensive reference for all API functions and classes.
# - **Function/Class List:**
#   - Detailed descriptions of all available functions and classes, including parameters and return values.
# - **Examples and Code Snippets:**
#   - Sample code for using various functions, demonstrating typical usage scenarios.
# - **Error Codes and Messages:**
#   - List of possible error codes/messages and explanations.
#
# ## 8. Usage Examples
# **Purpose:** Offer practical examples and scenarios demonstrating API usage.
# - **Common Use Cases:**
#   - Step-by-step examples of common data processing tasks.
# - **Code Walkthroughs:**
#   - Detailed walkthroughs of sample scripts using the API.
# - **Best Practices:**
#   - Recommendations for optimal use of the API based on real-world scenarios.
#
# ## 9. Troubleshooting
# **Purpose:** Assist users in resolving common issues when using the API.
# - **FAQ:**
#   - Frequently asked questions with concise answers.
# - **Common Issues:**
#   - List of issues users might encounter along with solutions.
# - **Support and Resources:**
#   - Information on how to get further help and access resources.
#
# ## 10. Release Notes
# **Purpose:** Keep users informed about the latest updates and changes to the API.
# - **Version History:**
#   - Summary of major and minor updates.
# - **New Features:**
#   - Details on added features and capabilities.
# - **Bug Fixes and Improvements:**
#   - List of resolved issues in each release.
#
# ---
#
# This outline serves as a guide to drafting comprehensive technical documentation for the Python-based data processing API, ensuring that users can effectively install, understand, and utilize its capabilities.
#
# 🔎 Synthesizer LLM Response for Section '1. Introduction':
#  ## 1. Introduction
#
# ### Purpose
# Welcome to the Python Data Processing API documentation! This API has been thoughtfully designed to streamline your data processing tasks, focusing specifically on handling CSV and JSON data. Whether you're looking to validate, transform, or export your data, this API offers a robust set of features to make these tasks efficient and effective.
#
# ### Brief Description
# This Python-based data processing API is a powerful tool for developers and data scientists, simplifying the complexities of manipulating data stored in CSV and JSON formats. It encompasses various functionalities such as ensuring data integrity through validation, transforming datasets according to specific business rules, and exporting the processed data into versatile formats suitable for a wide array of applications.
#
# ### Overview of Key Features
#
# #### 1. Data Validation
# Data validation is crucial to maintaining data integrity and ensuring datasets are error-free and usable. This API allows for comprehensive validation of CSV and JSON files, detecting inconsistencies, missing entries, datatype mismatches, and other common data issues before any data-driven decisions are made.
# - **Example Functionality:** Validate CSV and JSON data against predefined schemas to ensure data quality.
#
# #### 2. Data Transformation
# Transform your raw data into a format that better suits your analysis and reporting needs. This API provides customizable transformation options, enabling operations such as data normalization, aggregation, filtering, and reshaping.
# - **Example Functionality:** Convert date formats, merge datasets, and apply mathematical transformations to data columns.
#
# #### 3. Export Capabilities
# After validation and transformation, the API facilitates the export of datasets into various formats, making it easy to integrate with other systems or applications. Supported export formats include refined CSV, JSON, and even direct database imports if necessary.
# - **Example Functionality:** Export processed data into a clean CSV file for sharing with stakeholders or import data into SQL databases for further usage.
#
# ### Use Case Examples
#
# - **Data Cleaning:** Automatically clean large datasets by identifying and rectifying data quality issues, which is critical in preparing data for analysis or reporting.
#
# - **Data Integration:** Seamlessly integrate datasets from multiple sources by resolving data format inconsistencies and combining information into a unified structure.
#
# - **ETL Processes:** Use the API as part of your ETL (Extract, Transform, Load) pipeline to automate data extraction, transformation based on custom logic, and loading of data into analytics systems or data warehouses.
#
# By leveraging this API, users can significantly reduce the time and effort required for data manipulation tasks, allowing for more focus on extracting insights and making data-driven decisions.
#
# 🔎 Synthesizer LLM Response for Section '2. Getting Started':
#  ```markdown
# ## 2. Getting Started
#
# Welcome to the Getting Started guide for the Python-based data processing API. This section will help you install and configure the API, so you can efficiently handle CSV and JSON data, perform data validation, and export data to multiple formats.
#
# ### 2.1 Purpose
#
# The purpose of this guide is to ensure you can set up the API environment with ease and prepare it for efficient data processing. By following these directions, you will soon be ready to validate, transform, and export your data.
#
# ### 2.2 System Requirements
#
# Before installing the API, ensure your system meets the following requirements:
#
# - **Operating Systems:**
#   - Windows 10 or later
#   - macOS 10.15 (Catalina) or later
#   - Linux distributions such as Ubuntu 18.04 or later
#
# - **Python Version:**
#   - Python 3.7 or later
#
# - **Dependencies:**
#   - pandas>=1.3.0
#   - numpy>=1.21.0
#   - requests>=2.25.0
#
# These dependencies will be installed automatically if you follow the instructions below.
#
# ### 2.3 Installation Instructions
#
# To install the API, you must have Python installed on your system. The recommended way to install the API is via the Python package manager, pip:
#
# #### Step-by-Step Procedure
#
# 1. **Verify Python and pip Installation**
#
#    Ensure Python and pip are installed and up to date. Run the following commands in your terminal or command prompt:
#
#    ```bash
#    python --version
#    pip --version
#    ```
#
#    If Python or pip is not installed, please download and install Python from [the official Python website](https://www.python.org/downloads/).
#
# 2. **Install the API Package**
#
#    Run the following pip command to install the API:
#
#    ```bash
#    pip install data-processing-api
#    ```
#
#    This command installs the API along with all its dependencies.
#
# 3. **Verify the Installation**
#
#    To verify the installation, open a Python shell and try importing the main module:
#
#    ```python
#    import data_processing_api
#    print(data_processing_api.__version__)
#    ```
#
#    If you see the version number without any errors, the installation is successful.
#
# ### 2.4 Configuration
#
# Once the API is installed, follow these steps to configure it for your development environment.
#
# #### Basic Configuration
#
# 1. **Set Environment Variables**
#
#    Create a `.env` file in your project directory to specify necessary environment variables. Below is an example configuration:
#
#    ```plaintext
#    DATA_API_KEY=your_api_key_here
#    EXPORT_FORMAT=csv
#    ```
#
#    Replace `your_api_key_here` with your actual API key and set the export format as needed (`csv`, `json`, etc.).
#
# 2. **Configure API Settings**
#
#    The API allows for advanced configuration through a settings file. Create a configuration file, `config.yaml`, in your project directory with the following structure to customize options:
#
#    ```yaml
#    api:
#      key: your_api_key_here
#      base_url: "https://api.example.com"
#    data:
#      default_format: csv
#      validation: true  # Enable data validation
#    ```
#
#    Update the file with details pertinent to your usage scenario.
#
# 3. **Initialize the API**
#
#    Import the API in your Python code and initialize it with necessary settings:
#
#    ```python
#    from data_processing_api import DataAPI
#
#    config_path = "path_to_your_config_file.yaml"
#    data_api = DataAPI(config_path=config_path)
#    ```
#
# Congratulations! You have now installed and configured the Python-based data processing API. You're ready to start validating, transforming, and exporting data. Proceed to the API Reference and Usage Examples sections for further guidance.
# ```
#
#
# 🔎 Synthesizer LLM Response for Section '3. API Architecture':
#  ## 3. API Architecture
#
# The architecture of our Python-based data processing API is designed to efficiently handle CSV and JSON data, ensuring robustness in data validation, transformation, and export to multiple formats. This section details the key components of the API, provides a visual workflow diagram, and explains the modular interaction within the system.
#
# ### Overview of API Components
#
# The API is structured around several core components, each with a specific role in the data processing workflow:
#
# - **Data Ingestor:**
#   - **Role:** Responsible for receiving input data in CSV or JSON format. This component ensures that the data is correctly formatted and ready for processing.
#   - **Implementation:** Utilizes Python's `csv` and `json` libraries to read and parse data files.
#
# - **Data Validator:**
#   - **Role:** Ensures the integrity and validity of the input data according to predefined schema rules. It checks for missing fields, correct data types, and other validation criteria.
#   - **Implementation:** Employs libraries such as `jsonschema` for JSON data and custom validation logic for CSV.
#
# - **Data Transformer:**
#   - **Role:** Processes validated data to transform it as needed. This includes operations such as scaling, type conversions, and data enrichment.
#   - **Implementation:** Uses Pandas for transformations, leveraging its powerful data manipulation capabilities.
#
# - **Data Exporter:**
#   - **Role:** Handles the export of processed data to various formats, including CSV, JSON, and other specified formats.
#   - **Implementation:** Supports writing functions using Pandas and native `csv` and `json` utilities for consistent data export.
#
# ### Workflow Diagram
#
# Below is a visual representation of the data flow through the API, illustrating the progression from inputting data to exporting the final output:
#
# ```mermaid
# graph LR
#   A[Input Data] --> B[Data Ingestor]
#   B --> C[Data Validator]
#   C --> D[Data Transformer]
#   D --> E[Data Exporter]
#   E --> F[Output Data]
# ```
#
# ### Modular Description
#
# The API is designed with a modular architecture, promoting separation of concerns and ease of maintenance. Here’s a deeper look into the interaction between modules:
#
# - **Modular Interaction:**
#   - Each module is independently responsible for a specific part of the workflow, communicating with others through well-defined interfaces.
#   - The **Data Ingestor** module sends structured data to the **Data Validator** once ingestion is complete, passing only what can be parsed successfully.
#   - The **Data Validator** communicates validation results back to the **Data Ingestor** and forwards validated data to the **Data Transformer**. If validation fails, appropriate error messages are returned.
#   - The **Data Transformer**, once done with modifications, hands over the processed data to the **Data Exporter**.
#   - The **Data Exporter** module finalizes the pipeline by saving or transmitting the transformed data in the desired format, ready for client integration.
#
# Each of these components can be extended or modified without impacting others, supporting the addition of new features, such as more complex transformations or new export formats, ensuring that the API remains scalable and adaptable to evolving needs. This modular approach not only aids development and troubleshooting but also facilitates testing by segmenting the workflow into manageable pieces.
#
# 🔎 Synthesizer LLM Response for Section '4. Data Validation':
#  ## 4. Data Validation
#
# Data validation is a critical step in ensuring the integrity and quality of data before processing. The API's data validation capabilities ensure that your CSV and JSON data meets specified criteria before undergoing any transformations or exports. This section details the available validation features, configuration options, and error-handling procedures to optimize the use of this API for your data validation needs.
#
# ### Validation Features
#
# The API provides robust validation features to ensure your data adheres to the desired specifications. Key validation types include:
#
# - **Schema Validation:**
#   Ensures that data structures match predefined schemas. This is crucial for verifying that your data includes necessary fields and conforms to the expected hierarchical layout.
#
# - **Data Type Checks:**
#   Validates that data types are consistent with expectations. For instance, fields expected to be integers or floats are checked to ensure they don't contain invalid types like strings.
#
# ### Configuration and Customization
#
# The API offers flexibility to configure and customize validation rules according to your needs.
#
# #### Setting Up Validation Rules
#
# 1. **Define Validation Schema:**
#    You must first define a schema that represents the structure of your data. This can be a JSON schema for JSON data or a set of validation rules for CSV files.
#
# 2. **Implement Validation in Code:**
#    Use the following example to set up validation for a JSON schema:
#
#    ```python
#    from your_api_module import DataValidator
#
#    # Define the JSON schema
#    json_schema = {
#        "type": "object",
#        "properties": {
#            "name": {"type": "string"},
#            "age": {"type": "integer"},
#            "email": {"type": "string", "format": "email"},
#        },
#        "required": ["name", "age"]
#    }
#
#    # Initialize the DataValidator with the schema
#    validator = DataValidator(schema=json_schema)
#
#    # Validate your data
#    data = {"name": "John Doe", "age": 30, "email": "john.doe@example.com"}
#    is_valid = validator.validate(data)
#    ```
#
# #### Predefined and Custom Rules
#
# - **Predefined Rules:**
#   The API includes several built-in validation rules to get you started quickly. These rules cover common validation needs, such as required fields and data format checks.
#
# - **Custom Rules:**
#   You can create custom validation rules to address specific requirements.
#
#   ```python
#   # Custom validation function
#   def validate_phone_number(data):
#       return isinstance(data.get('phone'), str) and len(data['phone']) == 10
#
#   # Configure the validator with a custom rule
#   validator.add_custom_rule('phone', validate_phone_number)
#   ```
#
# ### Error Handling
#
# Handling validation errors effectively is vital for debugging and maintaining the integrity of your data processing workflow.
#
# #### Procedures
#
# 1. **Capture Validation Errors:**
#    The API captures all validation errors and makes them accessible through exception handling mechanisms.
#
#    ```python
#    try:
#        validator.validate(data)
#    except ValidationError as e:
#        print(f"Validation error: {e}")
#    ```
#
# 2. **Logging:**
#    Errors are logged to provide insights into validation failures, which helps in diagnosing issues and improving data quality.
#
#    ```python
#    import logging
#
#    # Configure logging
#    logging.basicConfig(level=logging.ERROR)
#    logger = logging.getLogger(__name__)
#
#    try:
#        validator.validate(data)
#    except ValidationError as e:
#        logger.error(f"Validation failed for data: {data} with error: {e}")
#    ```
#
# By using these comprehensive validation features, you can significantly improve the quality and reliability of your data processing tasks with this powerful Python-based API.
#
# 🔎 Synthesizer LLM Response for Section '5. Data Transformation':
#  ## 5. Data Transformation
#
# ### Purpose
#
# The Data Transformation section of the API provides functionalities that allow users to manipulate and modify their data to fit specific use cases. This feature is crucial for preparing data before analysis or export, enabling users to tailor their datasets to meet analytical needs, ensure consistency, and improve data quality.
#
# ### Transformation Capabilities
#
# The API supports a range of transformation functions, designed to accommodate different data processing requirements:
#
# - **Data Normalization**: Standardize data to a specified scale or format.
# - **Data Filtering**: Select a subset of data based on specified conditions.
# - **Column Renaming**: Change column names to more meaningful representations.
# - **Data Type Conversion**: Convert data types for consistency across datasets.
# - **Missing Data Handling**: Fill, remove, or interpolate missing data entries.
# - **Aggregation**: Summarize data through aggregation functions like sum, average, min, max.
# - **Custom Transformations**: Apply user-defined transformations using lambda functions or custom function definitions.
#
# ### Applying Transformations
#
# To apply transformations, the API provides a set of methods that can be sequentially applied to datasets. Below are the instructions and examples for implementing these transformations:
#
# #### Data Normalization
#
# Normalization is often necessary when preparing data for machine learning algorithms or other analyses. This API provides methods to normalize data within a specified range.
#
# ```python
# from dataproc import DataProcessor
#
# data = DataProcessor.load_csv('input_data.csv')
#
# # Normalize the 'sales' column between 0 and 1
# normalized_data = data.normalize(column='sales', method='min-max')
#
# normalized_data.save_csv('normalized_output.csv')
# ```
#
# #### Data Filtering
#
# Filter data based on specific conditions to focus on relevant information.
#
# ```python
# # Filter out rows where 'age' is less than 18
# filtered_data = data.filter(condition=lambda x: x['age'] >= 18)
#
# filtered_data.save_json('filtered_output.json')
# ```
#
# #### Column Renaming
#
# Rename columns for clarity or consistency.
#
# ```python
# # Rename columns 'old_name' to 'new_name'
# renamed_data = data.rename_columns({'old_name': 'new_name'})
#
# renamed_data.save_csv('renamed_output.csv')
# ```
#
# #### Data Type Conversion
#
# Ensure data types are appropriate for their respective columns.
#
# ```python
# # Convert 'birth_date' column to datetime
# converted_data = data.convert_data_type(column='birth_date', new_type='datetime')
#
# converted_data.save_csv('converted_output.csv')
# ```
#
# #### Missing Data Handling
#
# Handle missing data effectively through removal or imputation.
#
# ```python
# # Fill missing entries in 'income' column with the mean value
# filled_data = data.fill_missing(column='income', method='mean')
#
# filled_data.save_csv('filled_output.csv')
# ```
#
# #### Aggregation
#
# Aggregate data to obtain summary statistics.
#
# ```python
# # Aggregate data to find the sum of 'sales' by 'region'
# aggregated_data = data.aggregate(by='region', column='sales', agg_func='sum')
#
# aggregated_data.save_json('aggregated_output.json')
# ```
#
# #### Custom Transformations
#
# Tailor the transformations to specific needs using custom functions.
#
# ```python
# # Apply a custom transformation to double the value of 'profit'
# def double_profit(row):
#     row['profit'] *= 2
#     return row
#
# custom_transformed_data = data.apply_custom_transformation(func=double_profit)
#
# custom_transformed_data.save_json('custom_transformed_output.json')
# ```
#
# Through these transformation capabilities, the API offers extensive tools to refine and prepare datasets for diverse processing workflows. Users can chain multiple transformations in their preferred sequence to effectively manipulate data as necessary before further analysis or export.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 9
#       2 if __name__ == "__main__":
#       3     requirements = """
#       4     Create comprehensive documentation for a Python-based data processing API that handles CSV and JSON data.
#       5     The API should support data validation, transformation, and export to multiple formats.
#       6     Include installation instructions, API reference, and usage examples.
#       7     """
# ----> 9     result = generate_documentation(requirements)
#      11     # Save the result to a file
#      12     with open("generated_documentation.md", "w") as f:
#
# Cell In[5], line 58, in generate_documentation(requirements)
#      56 graph = create_workflow_graph()
#      57 config = {"recursion_limit": 50}  # Adjust based on your process needs
# ---> 58 final_state = graph.invoke(initial_state, config=config)
#      60 return final_state["complete_document"]
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/langgraph/pregel/__init__.py:2142, in Pregel.invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, **kwargs)
#    2140 else:
#    2141     chunks = []
# -> 2142 for chunk in self.stream(
#    2143     input,
#    2144     config,
#    2145     stream_mode=stream_mode,
#    2146     output_keys=output_keys,
#    2147     interrupt_before=interrupt_before,
#    2148     interrupt_after=interrupt_after,
#    2149     debug=debug,
#    2150     **kwargs,
#    2151 ):
#    2152     if stream_mode == "values":
#    2153         latest = chunk
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/langgraph/pregel/__init__.py:1797, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    1791     # Similarly to Bulk Synchronous Parallel / Pregel model
#    1792     # computation proceeds in steps, while there are channel updates.
#    1793     # Channel updates from step N are only visible in step N+1
#    1794     # channels are guaranteed to be immutable for the duration of the step,
#    1795     # with channel updates applied only at the transition between steps.
#    1796     while loop.tick(input_keys=self.input_channels):
# -> 1797         for _ in runner.tick(
#    1798             loop.tasks.values(),
#    1799             timeout=self.step_timeout,
#    1800             retry_policy=self.retry_policy,
#    1801             get_waiter=get_waiter,
#    1802         ):
#    1803             # emit output
#    1804             yield from output()
#    1805 # emit output
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/langgraph/pregel/runner.py:230, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     228 t = tasks[0]
#     229 try:
# --> 230     run_with_retry(
#     231         t,
#     232         retry_policy,
#     233         configurable={
#     234             CONFIG_KEY_SEND: partial(writer, t),
#     235             CONFIG_KEY_CALL: partial(call, t),
#     236         },
#     237     )
#     238     self.commit(t, None)
#     239 except Exception as exc:
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/langgraph/pregel/retry.py:40, in run_with_retry(task, retry_policy, configurable)
#      38     task.writes.clear()
#      39     # run the task
# ---> 40     return task.proc.invoke(task.input, config)
#      41 except ParentCommand as exc:
#      42     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/langgraph/utils/runnable.py:546, in RunnableSeq.invoke(self, input, config, **kwargs)
#     542 config = patch_config(
#     543     config, callbacks=run_manager.get_child(f"seq:step:{i + 1}")
#     544 )
#     545 if i == 0:
# --> 546     input = step.invoke(input, config, **kwargs)
#     547 else:
#     548     input = step.invoke(input, config)
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/langgraph/utils/runnable.py:310, in RunnableCallable.invoke(self, input, config, **kwargs)
#     308 else:
#     309     context.run(_set_config_context, config)
# --> 310     ret = context.run(self.func, *args, **kwargs)
#     311 if isinstance(ret, Runnable) and self.recurse:
#     312     return ret.invoke(input, config)
#
# Cell In[4], line 165, in refine_section(state)
#     146 latest_feedback = state["feedback"][-1]
#     148 prompt = ChatPromptTemplate.from_messages([
#     149     SystemMessage(content="""You are a technical documentation writer.
#     150     Revise the content based on the feedback provided.
#    (...)
#     162     """)
#     163 ])
# --> 165 response = synthesizer_model.invoke(prompt.format_messages())
#     167 # Update the refined content
#     168 refined_content = response.content
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:284, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     273 def invoke(
#     274     self,
#     275     input: LanguageModelInput,
#    (...)
#     279     **kwargs: Any,
#     280 ) -> BaseMessage:
#     281     config = ensure_config(config)
#     282     return cast(
#     283         ChatGeneration,
# --> 284         self.generate_prompt(
#     285             [self._convert_input(input)],
#     286             stop=stop,
#     287             callbacks=config.get("callbacks"),
#     288             tags=config.get("tags"),
#     289             metadata=config.get("metadata"),
#     290             run_name=config.get("run_name"),
#     291             run_id=config.pop("run_id", None),
#     292             **kwargs,
#     293         ).generations[0][0],
#     294     ).message
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:860, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     852 def generate_prompt(
#     853     self,
#     854     prompts: list[PromptValue],
#    (...)
#     857     **kwargs: Any,
#     858 ) -> LLMResult:
#     859     prompt_messages = [p.to_messages() for p in prompts]
# --> 860     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:690, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     687 for i, m in enumerate(messages):
#     688     try:
#     689         results.append(
# --> 690             self._generate_with_cache(
#     691                 m,
#     692                 stop=stop,
#     693                 run_manager=run_managers[i] if run_managers else None,
#     694                 **kwargs,
#     695             )
#     696         )
#     697     except BaseException as e:
#     698         if run_managers:
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:925, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     923 else:
#     924     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 925         result = self._generate(
#     926             messages, stop=stop, run_manager=run_manager, **kwargs
#     927         )
#     928     else:
#     929         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:790, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     788     generation_info = {"headers": dict(raw_response.headers)}
#     789 else:
# --> 790     response = self.client.create(**payload)
#     791 return self._create_chat_result(response, generation_info)
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/openai/_utils/_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/openai/resources/chat/completions.py:863, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     821 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     822 def create(
#     823     self,
#    (...)
#     860     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     861 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     862     validate_response_format(response_format)
# --> 863     return self._post(
#     864         "/chat/completions",
#     865         body=maybe_transform(
#     866             {
#     867                 "messages": messages,
#     868                 "model": model,
#     869                 "audio": audio,
#     870                 "frequency_penalty": frequency_penalty,
#     871                 "function_call": function_call,
#     872                 "functions": functions,
#     873                 "logit_bias": logit_bias,
#     874                 "logprobs": logprobs,
#     875                 "max_completion_tokens": max_completion_tokens,
#     876                 "max_tokens": max_tokens,
#     877                 "metadata": metadata,
#     878                 "modalities": modalities,
#     879                 "n": n,
#     880                 "parallel_tool_calls": parallel_tool_calls,
#     881                 "prediction": prediction,
#     882                 "presence_penalty": presence_penalty,
#     883                 "reasoning_effort": reasoning_effort,
#     884                 "response_format": response_format,
#     885                 "seed": seed,
#     886                 "service_tier": service_tier,
#     887                 "stop": stop,
#     888                 "store": store,
#     889                 "stream": stream,
#     890                 "stream_options": stream_options,
#     891                 "temperature": temperature,
#     892                 "tool_choice": tool_choice,
#     893                 "tools": tools,
#     894                 "top_logprobs": top_logprobs,
#     895                 "top_p": top_p,
#     896                 "user": user,
#     897             },
#     898             completion_create_params.CompletionCreateParams,
#     899         ),
#     900         options=make_request_options(
#     901             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     902         ),
#     903         cast_to=ChatCompletion,
#     904         stream=stream or False,
#     905         stream_cls=Stream[ChatCompletionChunk],
#     906     )
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/openai/_base_client.py:1283, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1269 def post(
#    1270     self,
#    1271     path: str,
#    (...)
#    1278     stream_cls: type[_StreamT] | None = None,
#    1279 ) -> ResponseT | _StreamT:
#    1280     opts = FinalRequestOptions.construct(
#    1281         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1282     )
# -> 1283     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/openai/_base_client.py:960, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     957 else:
#     958     retries_taken = 0
# --> 960 return self._request(
#     961     cast_to=cast_to,
#     962     options=options,
#     963     stream=stream,
#     964     stream_cls=stream_cls,
#     965     retries_taken=retries_taken,
#     966 )
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/openai/_base_client.py:996, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     993 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     995 try:
# --> 996     response = self._client.send(
#     997         request,
#     998         stream=stream or self._should_stream_response_body(request=request),
#     999         **kwargs,
#    1000     )
#    1001 except httpx.TimeoutException as err:
#    1002     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Desktop/Riddhi/KrishCourse/LangchainIntro/venv/lib/python3.12/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File /opt/anaconda3/lib/python3.12/ssl.py:1232, in SSLSocket.recv(self, buflen, flags)
#    1228     if flags != 0:
#    1229         raise ValueError(
#    1230             "non-zero flags not allowed in calls to recv() on %s" %
#    1231             self.__class__)
# -> 1232     return self.read(buflen)
#    1233 else:
#    1234     return super().recv(buflen, flags)
#
# File /opt/anaconda3/lib/python3.12/ssl.py:1105, in SSLSocket.read(self, len, buffer)
#    1103         return self._sslobj.read(len, buffer)
#    1104     else:
# -> 1105         return self._sslobj.read(len)
#    1106 except SSLError as x:
#    1107     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
